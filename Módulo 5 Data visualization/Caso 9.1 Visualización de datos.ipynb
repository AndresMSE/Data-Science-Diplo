# %%
#Importar librerías necesarias
import pandas as pd
import numpy as np
import cufflinks as cf
import chart_studio.plotly as py
import plotly.express as px
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
init_notebook_mode(connected = True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('Unicorn_Companies.csv')   #Importar los datos
df.head()   #Mostrar los primeros 5 elementos
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           $140    4/7/2017          China        Beijing
# 1      SpaceX         $100.3   12/1/2012  United States      Hawthorne
# 2      Stripe            $95   1/23/2014  United States  San Francisco
# 3      Klarna          $45.6  12/12/2011         Sweden      Stockholm
# 4  Epic Games            $42  10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
#   Founded Year Total Raised Financial Stage Investors Count Deal Terms  \
# 0         2012       $7.44B             IPO              28          8
# 1         2002      $6.874B            None              29         12
# 2         2010      $2.901B           Asset              39         12
# 3         2005      $3.472B        Acquired              56         13
# 4         1991      $4.377B        Acquired              25          5
#
#   Portfolio Exits
# 0               5
# 1            None
# 2               1
# 3               1
# 4               2

# %% [markdown]
# # 1) Limpieza del dataset
# Verificamos valores nulos en los datos y posteriormente se limpiará columna a columna analizando cada caso

# %%
df_clean = df   #Crear un nuevo dataframe para realizar la limpieza

# %%
df_clean.isnull().any()   #Verificar si existe algún valor nulo
# Out:
# Company              False
# Valuation ($B)       False
# Date Joined          False
# Country              False
# City                 False
# Industry             False
# Select Inverstors    False
# Founded Year         False
# Total Raised         False
# Financial Stage      False
# Investors Count      False
# Deal Terms           False
# Portfolio Exits      False
# dtype: bool

# %% [markdown]
# ## 1.1) Columna 1: Company
#
# Verifiquemos si no hay compañias repetidas o que compartan el nombre

# %%
df_clean['Company'].value_counts()
# Out:
# Bolt                          2
# Fabric                        2
# YipitData                     1
# TalkingData                   1
# Unqork                        1
#                              ..
# Hasura                        1
# Five Star Business Finance    1
# Sift                          1
# JUUL Labs                     1
# Snapdeal                      1
# Name: Company, Length: 1035, dtype: int64

# %% [markdown]
# Tenemos dos nombres repetidos, veamos si se tratan de compañias distintas

# %%
df_clean[df_clean['Company']=='Bolt']
# Out:
#    Company Valuation ($B) Date Joined        Country           City  \
# 37    Bolt            $11   10/8/2021  United States  San Francisco
# 63    Bolt           $8.4   5/29/2018        Estonia        Tallinn
#
#                  Industry                                  Select Inverstors  \
# 37                Fintech  Activant Capital, Tribe Capital, General Atlantic
# 63  Auto & transportation             Didi Chuxing, Diamler, TMT Investments
#
#    Founded Year Total Raised Financial Stage Investors Count Deal Terms  \
# 37         2014        $963M            None              37          3
# 63         2013      $1.971B            None              28          5
#
#    Portfolio Exits
# 37            None
# 63            None

# %% [markdown]
# En este caso, se tratan de compañías distintas por lo que solamente las renombraremos indicando su país de origen

# %%
df_clean[(df_clean['Company']=='Bolt') &
         (df_clean['Country']=='United States')] = df_clean[(df_clean['Company']=='Bolt') &
                                                            (df_clean['Country']=='United States')].replace({'Bolt':'Bolt-US'})

# %%
df_clean[(df_clean['Company']=='Bolt') &
         (df_clean['Country']=='Estonia')] = df_clean[(df_clean['Company']=='Bolt') & 
                                                      (df_clean['Country']=='Estonia')].replace({'Bolt':'Bolt-EE'})

# %%
df_clean[df_clean['Company']=='Fabric']
# Out:
#     Company Valuation ($B) Date Joined        Country      City  \
# 578  Fabric           $1.5   2/24/2022  United States  Bellevue
# 976  Fabric             $1  10/26/2021  United States  New York
#
#                                 Industry  \
# 578      E-commerce & direct-to-consumer
# 976  Supply chain, logistics, & delivery
#
#                                      Select Inverstors Founded Year  \
# 578  Redpoint Ventures, Norwest Venture Partners, S...         2017
# 976               Innovation Endeavors, Aleph, Temasek         1999
#
#     Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 578     $292.58M            None              11          2            None
# 976         None            None               1          1            None

# %% [markdown]
# En este caso se tratan de dos compañías con mismo nombre, mismo país pero distinta ciudad, procederemos de forma similar

# %%
df_clean[(df_clean['Company']=='Fabric') & 
         (df_clean['City']=='Bellevue')] = df_clean[(df_clean['Company']=='Fabric') & 
                                                    (df_clean['City']=='Bellevue')].replace({'Fabric':'Fabric-BV'})
df_clean[(df_clean['Company']=='Fabric') & 
         (df_clean['City']=='New York')] = df_clean[(df_clean['Company']=='Fabric') & 
                                                    (df_clean['City']=='New York')].replace({'Fabric':'Fabric-NY'})

# %% [markdown]
# ## 1.2) Columna 2: Valuation

# %%
df['Valuation ($B)'].describe()    #Información acerca de la columna
# Out:
# count     1037
# unique     200
# top         $1
# freq       244
# Name: Valuation ($B), dtype: object

# %% [markdown]
# Vemos que la columna hace referencia a un precio, sin embargo el objeto almacenado son `strings` por lo que se transformará a un valor numérico omitiendo también el símbolo del dolar *$*

# %%
df_clean['Valuation ($B)'] = df_clean['Valuation ($B)'].replace({'\$':''},
                                                                regex=True)   #Eliminar el símbolo '$'
df_clean['Valuation ($B)'] = df_clean['Valuation ($B)'].astype(float)    #Convertir los valores a punto flotante

# %%
df_clean['Valuation ($B)'].describe()
# Out:
# count    1037.000000
# mean        3.292083
# std         7.309781
# min         1.000000
# 25%         1.080000
# 50%         1.600000
# 75%         3.100000
# max       140.000000
# Name: Valuation ($B), dtype: float64

# %% [markdown]
# ## 1.3) Columna 3: Date Joined
#
# Aquí convertiremos la fecha de tipo `string` a `DateTime` dándole el formato aaaa/mm/dd

# %%
df_clean['Date Joined'] = pd.to_datetime(df_clean['Date Joined'],format ='%m/%d/%Y')
df_clean['Date Joined'] = df_clean['Date Joined'].dt.strftime('%Y-%m-%d')

# %%
df_clean['Date Joined']
# Out:
# 0       2017-04-07
# 1       2012-12-01
# 2       2014-01-23
# 3       2011-12-12
# 4       2018-10-26
#            ...
# 1032    2022-02-22
# 1033    2022-02-23
# 1034    2022-02-23
# 1035    2022-02-23
# 1036    2022-02-24
# Name: Date Joined, Length: 1037, dtype: object

# %% [markdown]
# ## 1.4 ) Columna 3: Country

# %%
df_clean['Country'].value_counts()
# Out:
# United States           536
# China                   168
# India                    63
# United Kingdom           42
# Germany                  24
# France                   24
# Israel                   20
# Canada                   19
# Brazil                   16
# Singapore                12
# South Korea              12
# Indonesia                 7
# Hong Kong                 6
# Australia                 6
# Japan                     6
# Sweden                    6
# Netherlands               6
# Mexico                    6
# Switzerland               5
# Ireland                   5
# Norway                    4
# Turkey                    3
# United Arab Emirates      3
# Belgium                   3
# Spain                     3
# Finland                   3
# Thailand                  2
# Philippines               2
# Denmark                   2
# Austria                   2
# South Africa              2
# Chile                     2
# Estonia                   2
# Vietnam                   2
# Colombia                  2
# Senegal                   1
# Croatia                   1
# Nigeria                   1
# Luxembourg                1
# Italy                     1
# Lithuania                 1
# Bahamas                   1
# Czech Republic            1
# Argentina                 1
# Malaysia                  1
# Bermuda                   1
# Name: Country, dtype: int64

# %% [markdown]
# No hay países repetidos indebidamente, no hace falta modificar nada

# %% [markdown]
# ## 1.5) Columna 6: Industry
#
# Verificamos si existe alguna categoría errónea o repedita

# %%
df_clean['Industry'].value_counts()
# Out:
# Fintech                                                               205
# Internet software & services                                          192
# E-commerce & direct-to-consumer                                       107
# Artificial intelligence                                                71
# Health                                                                 69
# Supply chain, logistics, & delivery                                    57
# Other                                                                  56
# Cybersecurity                                                          49
# Data management & analytics                                            41
# Mobile & telecommunications                                            37
# Hardware                                                               33
# Auto & transportation                                                  29
# Edtech                                                                 28
# Consumer & retail                                                      25
# Travel                                                                 14
# Artificial Intelligence                                                 7
# Hopu Investment Management, Boyu Capital, DC Thomson Ventures           1
# 500 Global, Rakuten Ventures, Golden Gate Ventures                      1
# B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution      1
# Sequoia Capital China, ING, Alibaba Entrepreneurs Fund                  1
# Kuang-Chi                                                               1
# Tiger Global Management, Tiger Brokers, DCM Ventures                    1
# Vision Plus Capital, GSR Ventures, ZhenFund                             1
# Jungle Ventures, Accel, Venture Highway                                 1
# Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures         1
# Finttech                                                                1
# Dragonfly Captial, Qiming Venture Partners, DST Global                  1
# Temasek, Guggenheim Investments, Qatar Investment Authority             1
# Sequoia Capital China, Shunwei Capital Partners, Qualgro                1
# Andreessen Horowitz, DST Global, IDG Capital                            1
# SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures                1
# Mundi Ventures, Doqling Capital Partners, Activant Capital              1
# Sequoia Capital, Thoma Bravo, Softbank                                  1
# Name: Industry, dtype: int64

# %%
df_clean[(df_clean['Industry']=='Finttech')]=df_clean[(df_clean['Industry']=='Finttech')].replace({'Finttech':'Fintech'},regex=True) 
#Añadimos la categoría mal escrita a la correcta

# %% [markdown]
# En esa columna encontramos una categoría mal escrita que aparecía como una categoría adicional, se ha corregido para añadirla a la categoría correspondiente,

# %% [markdown]
# ## 1.6) Columna 5: City

# %%
cities = [x[0] for x in df_clean.groupby('City')]
# cities

# %% [markdown]
# Notamos que existe un error en ciertos registros donde los datos de **Industría** están sobre la ciudad y los **Select Investors** sobre la de Industría

# %%
industries = [x[0] for x in df_clean.groupby('Industry')]
# industries

# %%
for x in cities:
    for y in industries:
        if x == y:
            df_replace = df_clean[df_clean['City'] == y]
            df_replace['Select Inverstors'] = df_replace['Industry'].values
            df_replace['Industry'] = df_replace['City'].values
            df_replace['City'] = None
            df_clean[df_clean['City'] == y] = df_replace

# %%
df_clean[df_clean['City'] == 'Fintech']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Financial Stage, Investors Count, Deal Terms, Portfolio Exits]
# Index: []

# %%
df_clean[df_clean['City']=='Artificial intelligence']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Financial Stage, Investors Count, Deal Terms, Portfolio Exits]
# Index: []

# %%
df_clean[df_clean['City']=='E-commerce & direct-to-consumer']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Financial Stage, Investors Count, Deal Terms, Portfolio Exits]
# Index: []

# %%
df_clean[df_clean['City']=='Fintech']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Financial Stage, Investors Count, Deal Terms, Portfolio Exits]
# Index: []

# %%
df_clean[df_clean['City']=='Internet software & services']
# Out:
# Empty DataFrame
# Columns: [Company, Valuation ($B), Date Joined, Country, City, Industry, Select Inverstors, Founded Year, Total Raised, Financial Stage, Investors Count, Deal Terms, Portfolio Exits]
# Index: []

# %% [markdown]
# ## 1.7) Columna 8: Year Founded
#
# Verificamos si es el tipo correcto de dato

# %%
df['Founded Year'].value_counts()    #Información acerca de la columna
# Out:
# 2015    144
# 2014    105
# 2016    101
# 2012     87
# 2013     85
# 2011     76
# 2017     67
# 2018     55
# None     43
# 2010     37
# 2019     34
# 2009     33
# 2008     23
# 2007     23
# 2020     23
# 2005     15
# 2006     13
# 2000     12
# 2021      8
# 2004      8
# 2001      8
# 1999      8
# 2003      7
# 1998      4
# 2002      3
# 1994      2
# 1995      2
# 1992      2
# 1991      1
# 1993      1
# 1990      1
# 1973      1
# 1996      1
# 1984      1
# 1997      1
# 1919      1
# 1979      1
# Name: Founded Year, dtype: int64

# %% [markdown]
# ## 1.8) Columna 9: Total Raised
#
# Aquí lo que tenemos que hacer es convertir el objeto a tipo `float` adecuado usando el sufijo de unidad.

# %%
df_clean["Total Raised Unity"] = df["Total Raised"].str[-1]

df_clean["Total Raised"] = df_clean["Total Raised"].replace({"\$": "", "B$": "", "M$": "", "None": np.nan, "K$": ""}, regex=True)
df_clean["Total Raised"] = df_clean["Total Raised"].astype(float)

for i, row in df_clean.iterrows():
    if row["Total Raised Unity"] == "B":
        df.loc[i, "Total Raised"] = row["Total Raised"] * 1_000_000_000
    elif row["Total Raised Unity"] == "M":
        df.loc[i, "Total Raised"] = row["Total Raised"] * 1_000_000
    elif row["Total Raised Unity"] == "K":
        df.loc[i, "Total Raised"] = row["Total Raised"] * 1_000

df_clean = df_clean.drop("Total Raised Unity", axis=1)
df_clean.head()
# Out:
#       Company  Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
#   Founded Year  Total Raised Financial Stage Investors Count Deal Terms  \
# 0         2012  7.440000e+09             IPO              28          8
# 1         2002  6.874000e+09            None              29         12
# 2         2010  2.901000e+09           Asset              39         12
# 3         2005  3.472000e+09        Acquired              56         13
# 4         1991  4.377000e+09        Acquired              25          5
#
#   Portfolio Exits
# 0               5
# 1            None
# 2               1
# 3               1
# 4               2

# %% [markdown]
# ## 1.9) Columna 10 y 13: Finantial State / Portfolio Exits
#
# Notamos que estas columnas tiene muchos valores faltantes

# %%
(df['Financial Stage'] == 'None').sum() / df.shape[0]
# Out:
# 0.95274831243973

# %%
(df['Portfolio Exits'] == 'None').sum() / df.shape[0]
# Out:
# 0.95274831243973

# %% [markdown]
# El 95% de esta columna es nula, por lo que podemos omitirla

# %%
df_clean = df_clean.drop('Financial Stage', axis=1)
df_clean = df_clean.drop('Portfolio Exits', axis=1)

# %% [markdown]
# ## DataSet Limpio

# %%
df_clean.head()
# Out:
#       Company  Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance           140.0  2017-04-07          China        Beijing
# 1      SpaceX           100.3  2012-12-01  United States      Hawthorne
# 2      Stripe            95.0  2014-01-23  United States  San Francisco
# 3      Klarna            45.6  2011-12-12         Sweden      Stockholm
# 4  Epic Games            42.0  2018-10-26  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
#   Founded Year  Total Raised Investors Count Deal Terms
# 0         2012  7.440000e+09              28          8
# 1         2002  6.874000e+09              29         12
# 2         2010  2.901000e+09              39         12
# 3         2005  3.472000e+09              56         13
# 4         1991  4.377000e+09              25          5

# %% [markdown]
# # Visualización

# %% [markdown]
# ## Treemap: País, Industria y Compañía - Valor en la bolsa

# %%
# Visualización por País, Industria y Compañía
fig = px.treemap(df_clean,path= ["Country","Industry", "Company"],
            values="Valuation ($B)", color_discrete_sequence=px.colors.qualitative.Pastel)

fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
# Out:
# <div>                            <div id="7ea5081c-eaed-4820-84f3-f65859c5b517" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ea5081c-eaed-4820-84f3-f65859c5b517")) {                    Plotly.newPlot(                        "7ea5081c-eaed-4820-84f3-f65859c5b517",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Valuation ($B)=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["United States/Internet software & services/1047 Games","China/Hardware/1KMXC","Canada/Cybersecurity/1Password","China/Artificial intelligence/4Paradigm","China/Supply chain, logistics, & delivery/56PINGTAI","China/Internet software & services/58 Daojia","United States/Artificial intelligence/6Sense","United States/Other/ABL Space Systems","China/Auto & transportation/AIWAYS","United States/Artificial intelligence/ASAPP","United Kingdom/Other/Accelerant","India/Fintech/Acko General Insurance","Switzerland/Cybersecurity/Acronis","United States/Internet software & services/ActiveCampaign","Canada/Artificial intelligence/Ada Support","United States/Fintech/Addepar","Singapore/Artificial intelligence/Advance Intelligence Group","Bermuda/Artificial intelligence/Afiniti","United States/Edtech/Age of Learning","United States/Fintech/AgentSync","Germany/Hardware/Agile Robots","China/Artificial intelligence/Aibee","United States/Internet software & services/Airbyte","United States/Internet software & services/Aircall","United States/Internet software & services/Airtable","Australia/Fintech/Airwallex","Finland/Internet software & services/Aiven","Indonesia/Fintech/Ajaib","Indonesia/E-commerce & direct-to-consumer/Akulaku","France/Fintech/Alan","United States/Internet software & services/Alation","United States/Fintech/Alchemy","United States/Health/Aledade","United States/Cybersecurity/Aleo","United States/Internet software & services/Algolia","United States/Fintech/Alloy","United States/Health/Alto Pharmacy","United States/Health/Alzheon","Hong Kong/Fintech/Amber Group","United States/Fintech/Amount","United States/Artificial intelligence/Amperity","United States/Fintech/Anchorage Digital","United States/Internet software & services/Andela","United States/Artificial intelligence/Anduril","France/E-commerce & direct-to-consumer/Ankorstore","United States/Artificial Intelligence/Anyscale","United States/Other/Apeel Sciences","United States/E-commerce & direct-to-consumer/AppDirect","United States/Data management & analytics/Applied Intuition","Canada/Edtech/ApplyBoard","United States/Mobile & telecommunications/AppsFlyer","South Korea/Health/Aprogen","China/Mobile & telecommunications/Apus Group","Israel/Cybersecurity/Aqua Security","United States/Cybersecurity/Arctic Wolf Networks","United States/Artificial intelligence/Argo AI","China/Health/Arrail Dental","United States/Edtech/Articulate","Thailand/Fintech/Ascend Money","United States/Internet software & services/Assembly","Canada/Supply chain, logistics, & delivery/Assent Compliance","United States/Mobile & telecommunications/Astranis Space Technologies","United States/Fintech/At-Bay","United States/Health/Athelas","United States/Health/Athletic Greens","United States/Mobile & telecommunications/Attentive","United States/Artificial intelligence/Augury","United States/Cybersecurity/Aura","United States/Internet software & services/Aurora Solar","United States/Artificial intelligence/Automation Anywhere","United States/Internet software & services/Automattic","United States/Artificial intelligence/Avant","United States/Internet software & services/Aviatrix","United States/E-commerce & direct-to-consumer/Away","Canada/Internet software & services/Axelar","United States/Other/Axiom Space","Un ...

# %% [markdown]
# ## Treemap: Industria, País y Compañía - Total recaudado

# %%
# Visualización por País, Industria y Compañía
fig = px.treemap(df_clean,path= ["Industry","Country", "Company"],
            values="Total Raised", color_discrete_sequence=px.colors.qualitative.Pastel)

fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
# Out:
# <div>                            <div id="97bd8320-6d56-43d2-9192-f66df08b43a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97bd8320-6d56-43d2-9192-f66df08b43a4")) {                    Plotly.newPlot(                        "97bd8320-6d56-43d2-9192-f66df08b43a4",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Total Raised=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Internet software & services/United States/1047 Games","Hardware/China/1KMXC","Cybersecurity/Canada/1Password","Artificial intelligence/China/4Paradigm","Supply chain, logistics, & delivery/China/56PINGTAI","Internet software & services/China/58 Daojia","Artificial intelligence/United States/6Sense","Other/United States/ABL Space Systems","Auto & transportation/China/AIWAYS","Artificial intelligence/United States/ASAPP","Other/United Kingdom/Accelerant","Fintech/India/Acko General Insurance","Cybersecurity/Switzerland/Acronis","Internet software & services/United States/ActiveCampaign","Artificial intelligence/Canada/Ada Support","Fintech/United States/Addepar","Artificial intelligence/Singapore/Advance Intelligence Group","Artificial intelligence/Bermuda/Afiniti","Edtech/United States/Age of Learning","Fintech/United States/AgentSync","Hardware/Germany/Agile Robots","Artificial intelligence/China/Aibee","Internet software & services/United States/Airbyte","Internet software & services/United States/Aircall","Internet software & services/United States/Airtable","Fintech/Australia/Airwallex","Internet software & services/Finland/Aiven","Fintech/Indonesia/Ajaib","E-commerce & direct-to-consumer/Indonesia/Akulaku","Fintech/France/Alan","Internet software & services/United States/Alation","Fintech/United States/Alchemy","Health/United States/Aledade","Cybersecurity/United States/Aleo","Internet software & services/United States/Algolia","Fintech/United States/Alloy","Health/United States/Alto Pharmacy","Health/United States/Alzheon","Fintech/Hong Kong/Amber Group","Fintech/United States/Amount","Artificial intelligence/United States/Amperity","Fintech/United States/Anchorage Digital","Internet software & services/United States/Andela","Artificial intelligence/United States/Anduril","E-commerce & direct-to-consumer/France/Ankorstore","Artificial Intelligence/United States/Anyscale","Other/United States/Apeel Sciences","E-commerce & direct-to-consumer/United States/AppDirect","Data management & analytics/United States/Applied Intuition","Edtech/Canada/ApplyBoard","Mobile & telecommunications/United States/AppsFlyer","Health/South Korea/Aprogen","Mobile & telecommunications/China/Apus Group","Cybersecurity/Israel/Aqua Security","Cybersecurity/United States/Arctic Wolf Networks","Artificial intelligence/United States/Argo AI","Health/China/Arrail Dental","Edtech/United States/Articulate","Fintech/Thailand/Ascend Money","Internet software & services/United States/Assembly","Supply chain, logistics, & delivery/Canada/Assent Compliance","Mobile & telecommunications/United States/Astranis Space Technologies","Fintech/United States/At-Bay","Health/United States/Athelas","Health/United States/Athletic Greens","Mobile & telecommunications/United States/Attentive","Artificial intelligence/United States/Augury","Cybersecurity/United States/Aura","Internet software & services/United States/Aurora Solar","Artificial intelligence/United States/Automation Anywhere","Internet software & services/United States/Automattic","Artificial intelligence/United States/Avant","Internet software & services/United States/Aviatrix","E-commerce & direct-to-consumer/United States/Away","Internet software & services/Canada/Axelar","Other/United States/Axiom Space","Cybe ...

# %% [markdown]
# **Insight 1** De estas dos visualizaciones generales notamos que en cuanto a empresas unicornio, EUA es el país lider seguido por China e India.
#
# **Insight 2** Por otro lado, respecto a las industrias con mayor capital recaudado son en primer lugar las Fintech seguidas por los E-commerce y los servicios y software por internet.

# %%
fig = px.histogram()

country_df = df_clean.groupby('Country')
country_max =country_df["Valuation ($B)"].sum().sort_values(ascending=False)[:10]

px.bar(country_max)
# Out:
# <div>                            <div id="ebf9d1da-5832-4606-a3b5-027e7326eb2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebf9d1da-5832-4606-a3b5-027e7326eb2a")) {                    Plotly.newPlot(                        "ebf9d1da-5832-4606-a3b5-027e7326eb2a",                        [{"alignmentgroup":"True","hovertemplate":"variable=Valuation ($B)<br>Country=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Valuation ($B)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Valuation ($B)","offsetgroup":"Valuation ($B)","orientation":"v","showlegend":true,"textposition":"auto","x":["United States","China","India","United Kingdom","Germany","Sweden","Australia","France","Canada","Israel"],"xaxis":"x","y":[1829.7400000000005,572.6900000000002,187.04999999999987,177.67999999999998,66.70000000000002,60.519999999999996,50.6,49.870000000000005,49.03,38.42],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":" ...

# %%
fig = px.histogram()

industry_df = df_clean.groupby('Industry')
industry_max =industry_df["Total Raised"].sum().sort_values(ascending=False)[:10]

px.bar(industry_max)
# Out:
# <div>                            <div id="db1210c3-6ea7-460f-97f1-6ba7677d5b41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db1210c3-6ea7-460f-97f1-6ba7677d5b41")) {                    Plotly.newPlot(                        "db1210c3-6ea7-460f-97f1-6ba7677d5b41",                        [{"alignmentgroup":"True","hovertemplate":"variable=Total Raised<br>Industry=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Total Raised","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Total Raised","offsetgroup":"Total Raised","orientation":"v","showlegend":true,"textposition":"auto","x":["Fintech","E-commerce & direct-to-consumer","Internet software & services","Other","Supply chain, logistics, & delivery","Artificial intelligence","Auto & transportation","Health","Hardware","Cybersecurity"],"xaxis":"x","y":[104370350000.0,75280400000.0,73891730000.0,43665740000.0,42888220000.0,42431620000.0,34383020000.0,33604110000.0,25395350000.0,22353400000.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...
